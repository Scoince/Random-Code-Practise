# %% [markdown]
# <a href="https://colab.research.google.com/github/Scoince/Random-Code-Practise/blob/main/count_space.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("a b  c".count(" "))
# Out:
# 3
